# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("./Datasets/IMDB Dataset.csv")

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.columns
# Out:
# Index(['review', 'sentiment'], dtype='str')

# %%
df.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df["sentiment"].unique()
# Out:
# <StringArray>
# ['positive', 'negative']
# Length: 2, dtype: str

# %%
df.duplicated().sum()
# Out:
# np.int64(418)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# plotting the count of positive and negative reviews
plot = df['sentiment'].value_counts().plot(kind='bar')
plot.set_xlabel('Sentiment')
plot.set_ylabel("Count")
plot.set_title("Count of Positive and Negative Reviews")
# Out:
# Text(0.5, 1.0, 'Count of Positive and Negative Reviews')

# %%
food=({
    ""
})

# %%
# recommendation system for food items based on their category, healthiness

# %%
food = {
    "Food Review": [
        "I love to eat Kadhai Paneer with Naan and Raita",
        "The Veg Biryani was flavorful and delicious",
        "Fresh fruit salad is my favorite breakfast",
        "Cheese Burger with fries tasted amazing",
        "Grilled chicken with vegetables was very healthy",
        "Masala Dosa with coconut chutney was excellent",
        "Pizza loaded with extra cheese was tasty",
        "Dal, rice, and mixed vegetables make a balanced meal",
        "Chocolate cake was sweet and enjoyable",
        "Sprouts salad with lemon is nutritious and refreshing",
    ],
    "Category": [
        "Veg",
        "Veg",
        "Veg",
        "Non-Healthy",
        "Non-Healthy",
        "Veg",
        "Veg",
        "Veg",
        "Non-Healthy",
        "Veg",
    ]
}

# %%
df = pd.DataFrame(food)
print(df)
# Out:
#                                          Food Review Category
# 0    I love to eat Kadhai Paneer with Naan and Raita      Veg
# 1        The Veg Biryani was flavorful and delicious      Veg
# 2         Fresh fruit salad is my favorite breakfast      Veg
# 3            Cheese Burger with fries tasted amazing  Non-Veg
# 4   Grilled chicken with vegetables was very healthy  Non-Veg
# 5     Masala Dosa with coconut chutney was excellent      Veg
# 6           Pizza loaded with extra cheese was tasty      Veg
# 7  Dal, rice, and mixed vegetables make a balance...      Veg
# 8             Chocolate cake was sweet and enjoyable      Veg
# 9  Sprouts salad with lemon is nutritious and ref...      Veg

# %%
# target variable mapping
df['Category'] = df['Category'].map({'Veg': 1, 'Non-Healthy': 0,'Non-Veg': 2,'Healthy': 3})

# %%
df
# Out:
#                                          Food Review  Category
# 0    I love to eat Kadhai Paneer with Naan and Raita         1
# 1        The Veg Biryani was flavorful and delicious         1
# 2         Fresh fruit salad is my favorite breakfast         1
# 3            Cheese Burger with fries tasted amazing         2
# 4   Grilled chicken with vegetables was very healthy         2
# 5     Masala Dosa with coconut chutney was excellent         1
# 6           Pizza loaded with extra cheese was tasty         1
# 7  Dal, rice, and mixed vegetables make a balance...         1
# 8             Chocolate cake was sweet and enjoyable         1
# 9  Sprouts salad with lemon is nutritious and ref...         1

# %%
import regex
regex

# %%
# anovo,t=test,chi sqaure,ztest,u test on drug data
