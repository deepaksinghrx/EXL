# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./Datasets/customer_drinks_preference.csv")

# %%
df
# Out:
#      c_id  Age  tea  coffee  greentea  cold_drink  gym_days  water_ltres  \
# 0       1   41    6       0         1           1         0          1.0
# 1       2   54    4       1         0           1         0          1.0
# 2       3   49    5       1         1           0         2          2.0
# 3       4   45    4       1         1           0         2          2.0
# 4       5   42    6       2         1           1         0          1.0
# ..    ...  ...  ...     ...       ...         ...       ...          ...
# 407   408   35    1       5         3           6         2          4.0
# 408   409   33    1       6         6           2         0          5.0
# 409   410   40    2       2         6           3         4          2.0
# 410   411   45    6       6         6           6         7         10.0
# 411   412   55    6       6         6           6         0         12.0
#
#      work_hrs  netflix_hrs
# 0           7           12
# 1           7            6
# ...

# %%
df.shape
# Out:
# (412, 10)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   c_id         412 non-null    int64
#  1   Age          412 non-null    int64
#  2   tea          412 non-null    int64
#  3   coffee       412 non-null    int64
#  4   greentea     412 non-null    int64
#  5   cold_drink   412 non-null    int64
#  6   gym_days     412 non-null    int64
#  7   water_ltres  412 non-null    float64
#  8   work_hrs     412 non-null    int64
#  9   netflix_hrs  412 non-null    int64
# dtypes: float64(1), int64(9)
# memory usage: 32.3 KB

# %%
df.describe()
# Out:
#              c_id         Age         tea      coffee    greentea  cold_drink  \
# count  412.000000  412.000000  412.000000  412.000000  412.000000  412.000000
# mean   206.500000   32.866505    2.016990    2.033981    1.682039    1.839806
# std    119.078406   10.375629    1.950033    1.947938    2.081869    2.035827
# min      1.000000   10.000000    0.000000    0.000000    0.000000    0.000000
# 25%    103.750000   23.750000    0.000000    0.750000    0.000000    0.000000
# 50%    206.500000   32.000000    1.000000    1.500000    1.000000    1.000000
# 75%    309.250000   41.000000    4.000000    4.000000    4.000000    4.000000
# max    412.000000   55.000000    6.000000    6.000000    6.000000    6.000000
#
#          gym_days  water_ltres    work_hrs  netflix_hrs
# count  412.000000   412.000000  412.000000   412.000000
# mean     1.946602     1.927184    6.793689    12.385922
# std      1.952492     1.270875    3.521731    10.238237
# ...

# %%
import numpy as np 
np.random.seed(42)

# %%
tea_lover = pd.DataFrame({
    "c_id" : range(1,101),
    "Age" : np.random.randint(35,56,100),
    "tea":np.random.randint(4,7,100),
    "coffee": np.random.randint(0,3,100),
    "greentea": np.random.randint(0,2,100),
    "cold_drink": np.random.randint(0,2,100),
    "gym_days": np.random.randint(0,3,100),
    "water_ltres": np.random.randint(1.5, 3.0,100).round(1),
    "work_hrs": np.random.randint(7,10, 100),
    "netflix_hrs": np.random.randint(5,15,100),

})

# %%
coffee_lover = pd.DataFrame({
    "c_id" : range(101,201),
    "Age" : np.random.randint(22,36,100),
    "tea":np.random.randint(0,3,100),
    "coffee": np.random.randint(4,7,100),
    "greentea": np.random.randint(0,2,100),
    "cold_drink": np.random.randint(0,3,100),
    "gym_days": np.random.randint(0,3,100),
    "water_ltres": np.random.randint(1.5, 3.0,100).round(1),
    "work_hrs": np.random.randint(9,13, 100),
    "netflix_hrs": np.random.randint(5,12,100),

})

# %%
health_lover = pd.DataFrame({
    "c_id" : range(201,301),
    "Age" : np.random.randint(25,51,100),
    "tea":np.random.randint(0,3,100),
    "coffee": np.random.randint(0,3,100),
    "greentea": np.random.randint(4,7,100),
    "cold_drink": np.random.randint(0,2,100),
    "gym_days": np.random.randint(4,7,100),
    "water_ltres": np.random.randint(3.0, 5.0,100).round(1),
    "work_hrs": np.random.randint(6,10, 100),
    "netflix_hrs": np.random.randint(2,8,100),

})

# %%
student_data = pd.DataFrame({
    "c_id" : range(301,401),
    "Age" : np.random.randint(18,25,100),
    "tea":np.random.randint(0,3,100),
    "coffee": np.random.randint(0,3,100),
    "greentea": np.random.randint(0,2,100),
    "cold_drink": np.random.randint(4,7,100),
    "gym_days": np.random.randint(0,3,100),
    "water_ltres": np.random.randint(1.0, 2.5,100).round(1),
    "work_hrs": np.random.randint(0,4, 100),
    "netflix_hrs": np.random.randint(15,40,100),

})

# %%
df = pd.concat([tea_lover, coffee_lover, health_lover, student_data], ignore_index=True)

# %%
df
# Out:
#      c_id  Age  tea  coffee  greentea  cold_drink  gym_days  water_ltres  \
# 0       1   41    6       0         1           1         0            1
# 1       2   54    4       1         0           1         0            1
# 2       3   49    5       1         1           0         2            2
# 3       4   45    4       1         1           0         2            2
# 4       5   42    6       2         1           1         0            1
# ..    ...  ...  ...     ...       ...         ...       ...          ...
# 395   396   23    0       1         0           5         2            1
# 396   397   19    0       0         0           4         0            1
# 397   398   21    0       2         1           4         0            1
# 398   399   24    0       1         0           4         0            1
# 399   400   20    0       0         1           5         0            1
#
#      work_hrs  netflix_hrs
# 0           7           12
# 1           7            6
# ...

# %%
noise = pd.DataFrame({
    "c_id" : range(401,411),
    "Age" : np.random.randint(8,60,10),
    "tea":np.random.randint(0,7,10),
    "coffee": np.random.randint(0,7,10),
    "greentea": np.random.randint(0,7,10),
    "cold_drink": np.random.randint(0,7,10),
    "gym_days": np.random.randint(0,7,10),
    "water_ltres": np.random.randint(1.0, 6.0,10).round(1),
    "work_hrs": np.random.randint(0,15, 10),
    "netflix_hrs": np.random.randint(0,50,10),

})

# %%
outliers = pd.DataFrame({
    "c_id" : [411,412],
    "Age" :[45,55],
    "tea":[6,6],
    "coffee": [6,6],
    "greentea": [6,6],
    "cold_drink": [6,6],
    "gym_days": [7,0],
    "water_ltres": [10.0,12.0],
    "work_hrs": [20,1],
    "netflix_hrs": [0,80]

})

# %%
df = pd.concat([df,noise],ignore_index=True)

# %%
df
# Out:
#      c_id  Age  tea  coffee  greentea  cold_drink  gym_days  water_ltres  \
# 0       1   41    6       0         1           1         0            1
# 1       2   54    4       1         0           1         0            1
# 2       3   49    5       1         1           0         2            2
# 3       4   45    4       1         1           0         2            2
# 4       5   42    6       2         1           1         0            1
# ..    ...  ...  ...     ...       ...         ...       ...          ...
# 405   406   55    2       3         1           6         6            1
# 406   407   28    6       2         2           6         4            3
# 407   408   35    1       5         3           6         2            4
# 408   409   33    1       6         6           2         0            5
# 409   410   40    2       2         6           3         4            2
#
#      work_hrs  netflix_hrs
# 0           7           12
# 1           7            6
# ...

# %%
df = pd.concat([df,outliers],ignore_index=True)

# %%
df.columns
# Out:
# Index(['c_id', 'Age', 'tea', 'coffee', 'greentea', 'cold_drink', 'gym_days',
#        'water_ltres', 'work_hrs', 'netflix_hrs'],
#       dtype='str')

# %%
df.to_csv("customer_drinks_preference.csv", index=False)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

X = df.drop('c_id', axis=1)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Elbow method
wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('K')
plt.ylabel('WCSS')
plt.show()
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
labels = kmeans.fit_predict(X_scaled)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
plt.scatter(X_pca[:,0], X_pca[:,1], c=labels)
plt.title('Clusters')
plt.show()

# %%
df
# Out:
#      c_id  Age  tea  coffee  greentea  cold_drink  gym_days  water_ltres  \
# 0       1   41    6       0         1           1         0          1.0
# 1       2   54    4       1         0           1         0          1.0
# 2       3   49    5       1         1           0         2          2.0
# 3       4   45    4       1         1           0         2          2.0
# 4       5   42    6       2         1           1         0          1.0
# ..    ...  ...  ...     ...       ...         ...       ...          ...
# 407   408   35    1       5         3           6         2          4.0
# 408   409   33    1       6         6           2         0          5.0
# 409   410   40    2       2         6           3         4          2.0
# 410   411   45    6       6         6           6         7         10.0
# 411   412   55    6       6         6           6         0         12.0
#
#      work_hrs  netflix_hrs
# 0           7           12
# 1           7            6
# ...

# %%
df.columns
# Out:
# Index(['c_id', 'Age', 'tea', 'coffee', 'greentea', 'cold_drink', 'gym_days',
#        'water_ltres', 'work_hrs', 'netflix_hrs'],
#       dtype='str')

# %%
features=['tea', 'coffee', 'greentea', 'cold_drink', 'gym_days',
       'water_ltres', 'work_hrs', 'netflix_hrs']

# %%
x=df[features]

# %%
x
# Out:
#      tea  coffee  greentea  cold_drink  gym_days  water_ltres  work_hrs  \
# 0      6       0         1           1         0          1.0         7
# 1      4       1         0           1         0          1.0         7
# 2      5       1         1           0         2          2.0         8
# 3      4       1         1           0         2          2.0         7
# 4      6       2         1           1         0          1.0         9
# ..   ...     ...       ...         ...       ...          ...       ...
# 407    1       5         3           6         2          4.0        10
# 408    1       6         6           2         0          5.0         1
# 409    2       2         6           3         4          2.0         7
# 410    6       6         6           6         7         10.0        20
# 411    6       6         6           6         0         12.0         1
#
#      netflix_hrs
# 0             12
# 1              6
# 2              9
# 3             11
# ...

# %%
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(x)

# %%
k=KMeans(n_clusters=4,random_state=42,n_init=10)

# %%
df["cluster"]=k.fit_predict(X_scaled)

# %%
df
# Out:
#      c_id  Age  tea  coffee  greentea  cold_drink  gym_days  water_ltres  \
# 0       1   41    6       0         1           1         0          1.0
# 1       2   54    4       1         0           1         0          1.0
# 2       3   49    5       1         1           0         2          2.0
# 3       4   45    4       1         1           0         2          2.0
# 4       5   42    6       2         1           1         0          1.0
# ..    ...  ...  ...     ...       ...         ...       ...          ...
# 407   408   35    1       5         3           6         2          4.0
# 408   409   33    1       6         6           2         0          5.0
# 409   410   40    2       2         6           3         4          2.0
# 410   411   45    6       6         6           6         7         10.0
# 411   412   55    6       6         6           6         0         12.0
#
#      work_hrs  netflix_hrs  cluster
# 0           7           12        2
# ...

# %%
df.groupby("cluster")[features].mean()
# Out:
#               tea    coffee  greentea  cold_drink  gym_days  water_ltres  \
# cluster
# 0        0.990196  4.970588  0.519608    1.117647  0.980392     1.480392
# 1        1.000000  1.067308  0.548077    4.980769  0.951923     1.173077
# 2        5.039604  1.029703  0.524752    0.623762  0.891089     1.435644
# 3        1.114286  1.104762  5.047619    0.600000  4.885714     3.580952
#
#           work_hrs  netflix_hrs
# cluster
# 0        10.450980     8.156863
# 1         1.509615    27.144231
# 2         7.881188     8.891089
# 3         7.428571     5.238095

# %%
df.columns
# Out:
# Index(['c_id', 'Age', 'tea', 'coffee', 'greentea', 'cold_drink', 'gym_days',
#        'water_ltres', 'work_hrs', 'netflix_hrs', 'cluster'],
#       dtype='str')

# %%
drinking_columns=['tea', 'coffee', 'greentea', 'cold_drink']

# %%
cluster_profiles=df.groupby("cluster")[drinking_columns].mean()

# %%
cluster_profiles
# Out:
#               tea    coffee  greentea  cold_drink
# cluster
# 0        0.990196  4.970588  0.519608    1.117647
# 1        1.000000  1.067308  0.548077    4.980769
# 2        5.039604  1.029703  0.524752    0.623762
# 3        1.114286  1.104762  5.047619    0.600000

# %%
dominant_drink=cluster_profiles.idxmax(axis=1)

# %%
dominant_drink
# Out:
# cluster
# 0        coffee
# 1    cold_drink
# 2           tea
# 3      greentea
# dtype: str

# %%
type(dominant_drink)
# Out:
# pandas.Series

# %%
dominant_drink.items
# Out:
# <bound method Series.items of cluster
# 0        coffee
# 1    cold_drink
# 2           tea
# 3      greentea
# dtype: str>

# %%
label_mapping={}

# %%
for cluster_id,drink in dominant_drink.items():
    if drink=="tea":
        label_mapping[cluster_id]="Tea Lover"
    elif drink=="coffee":
        label_mapping[cluster_id]="Coffee Lover"
    elif drink=="greentea":
        label_mapping[cluster_id]="Health Lover"
    elif drink=="cold_drink":
        label_mapping[cluster_id]="cold_drink Lover"

# %%
df["segment"]=df["cluster"].map(label_mapping)

# %%
label_mapping
# Out:
# {0: 'Coffee Lover', 1: 'cold_drink Lover', 2: 'Tea Lover', 3: 'Health Lover'}

# %%
df[features].head(1)
# Out:
#    tea  coffee  greentea  cold_drink  gym_days  water_ltres  work_hrs  \
# 0    6       0         1           1         0          1.0         7
#
#    netflix_hrs
# 0           12

# %%
df[['c_id','cluster','segment']].head(1)
# Out:
#    c_id  cluster    segment
# 0     1        2  Tea Lover

# %%
df.columns
# Out:
# Index(['c_id', 'Age', 'tea', 'coffee', 'greentea', 'cold_drink', 'gym_days',
#        'water_ltres', 'work_hrs', 'netflix_hrs', 'cluster', 'segment'],
#       dtype='str')

# %%
Nagendra=pd.DataFrame(
    [
        {
            "tea":1,
            "coffee":5,
            "greentea":0,
            "cold_drink":0,
            "gym_days":3,
            "water_ltres":4.0,
            'work_hrs': 5,
            'netflix_hrs':5,
        }
    ]
)

# %%
new_scaled=scaler.transform(Nagendra)

# %%
new_scaled
# Out:
# array([[-0.52215862,  1.52449684, -0.8089289 , -0.90481296,  0.54017047,
#          1.63299764, -0.50993963, -0.72228274]])

# %%
k1=k.predict(new_scaled)[0]

# %%
k1s=label_mapping[k1]

# %%
k1s
# Out:
# 'Coffee Lover'

# %%
label_mapping
# Out:
# {0: 'Coffee Lover', 1: 'cold_drink Lover', 2: 'Tea Lover', 3: 'Health Lover'}

# %%
df.columns
# Out:
# Index(['c_id', 'Age', 'tea', 'coffee', 'greentea', 'cold_drink', 'gym_days',
#        'water_ltres', 'work_hrs', 'netflix_hrs', 'cluster', 'segment'],
#       dtype='str')

# %%
df[df["segment"]=='Tea Lover'][['gym_days','water_ltres','work_hrs']].mean()
# Out:
# gym_days       0.891089
# water_ltres    1.435644
# work_hrs       7.881188
# dtype: float64

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
l = linkage(X_scaled, method='ward')

# %%
l
# Out:
# array([[2.11000000e+02, 2.21000000e+02, 0.00000000e+00, 2.00000000e+00],
#        [1.84000000e+02, 1.85000000e+02, 9.77918141e-02, 2.00000000e+00],
#        [1.79000000e+02, 1.94000000e+02, 9.77918141e-02, 2.00000000e+00],
#        ...,
#        [8.13000000e+02, 8.14000000e+02, 3.01423732e+01, 2.01000000e+02],
#        [8.19000000e+02, 8.20000000e+02, 4.35878906e+01, 3.12000000e+02],
#        [8.16000000e+02, 8.21000000e+02, 4.69175604e+01, 4.12000000e+02]],
#       shape=(411, 4))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
# dendrogram(l, labels=df["c_id"].values)
dendrogram(l, truncate_mode = "lastp",p=20) #for readability
plt.xlabel("user")
plt.ylabel("distance")
# Out:
# Text(0, 0.5, 'distance')

# %%
from sklearn.cluster import AgglomerativeClustering

hier = AgglomerativeClustering(n_clusters=4, linkage='ward')

# %%
hier.fit(X_scaled)
# Out:
# AgglomerativeClustering(n_clusters=4)

# %%
df["hier_cluster"] = hier.fit_predict(X_scaled)

# %%
cp = df.groupby('hier_cluster')[['tea','coffee','greentea','cold_drink']].mean()

# %%
pd.crosstab(df['cluster'],df['hier_cluster'])
# Out:
# hier_cluster    0    1    2    3
# cluster
# 0               1    0  101    0
# 1               4  100    0    0
# 2               1    0    0  100
# 3             105    0    0    0

# %% [markdown]
# first i selected the behaviour tea, coffee, greentea and cold drink columns and scaled the data using standard scaler
# then i used the linkage method to create a hierarchical clustering model using ward linkage and created a dendrogram to visualize and get the better idea of distabce. I then used AgglomerativeClustering to fit the model and assigned cluster labels to the original dataframe. Finally, I created a cluster profile to analyze the average beverage preferences for each cluster and created a crosstab to compare the hierarchical clusters with the original clusters.

# %%
#PCA never use pca on raw data

# %%
pca_features = features

# %%
pcaa=df[pca_features]

# %%
scale=scaler.fit_transform(pcaa)
scale
# Out:
# array([[ 2.0450174 , -1.04544055, -0.32800725, ..., -0.73045093,
#          0.05865341, -0.03774004],
#        [ 1.01814699, -0.53145307, -0.8089289 , ..., -0.73045093,
#          0.05865341, -0.62449093],
#        [ 1.5315822 , -0.53145307, -0.32800725, ...,  0.05736526,
#          0.34294993, -0.33111549],
#        ...,
#        [-0.00872341, -0.01746559,  2.07660103, ...,  0.05736526,
#          0.05865341,  0.64680265],
#        [ 2.0450174 ,  2.03848432,  2.07660103, ...,  6.35989479,
#          3.75450815, -1.21124181],
#        [ 2.0450174 ,  2.03848432,  2.07660103, ...,  7.93552717,
#         -1.6471257 ,  6.61210331]], shape=(412, 8))

# %%
from sklearn.decomposition import PCA

# %%
pcca=PCA(n_components=2)
pcca
# Out:
# PCA(n_components=2)

# %%
scale.shape
# Out:
# (412, 8)

# %%
pcall =PCA()
pcall.fit(scale)
# Out:
# PCA()

# %%
pca_variance=pcall.explained_variance_ratio_

# %%
pca_variance
# Out:
# array([0.41072832, 0.27505486, 0.16019948, 0.07130463, 0.02775723,
#        0.02254529, 0.01926908, 0.01314111])

# %%
pca_variance_cm = np.cumsum(pca_variance)

# %%
pca_variance_cm
# Out:
# array([0.41072832, 0.68578318, 0.84598266, 0.91728729, 0.94504452,
#        0.96758981, 0.98685889, 1.        ])

# %%
import numpy as np
import matplotlib.pyplot as plt

pca_variance_cm = np.cumsum(pca_variance)

plt.plot(range(1, len(pca_variance_cm)+1), pca_variance_cm, marker='o')
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA Cumulative Variance")
plt.grid()
plt.show()

# %%
data = {
    "person": [
        "P1",
        "P2",
        "P3",
        "P4",
        "P5",
        "P6",
        "P7",
        "P8",
        "P9",
        "P10",
        "P11",
        "P12",
        "P13",
        "P14",
        "P15",
        "P16",
        "P17",
        "P18",
        "P19",
        "P20",
        "P21",
        "P22",
        "P23",
        "P24",
        "P25",
        "P26",
        "P27",
        "P28",
        "P29",
        "P30",
        "P31",
        "P32",
        "P33",
        "P34",
        "P35",
        "P36",
        "P37",
        "P38",
        "P39",
        "P40",
        "P41",
        "P42",
        "P43",
        "P44",
        "P45",
        "P46",
        "P47",
        "P48",
        "P49",
        "P50",
    ],
    "tea": [
        8,
        9,
        7,
        8,
        9,
        10,
        8,
        7,
        9,
        8,
        1,
        0,
        2,
        1,
        2,
        0,
        1,
        2,
        1,
        0,
        5,
        6,
        5,
        4,
        6,
        5,
        5,
        6,
        4,
        5,
        9,
        8,
        10,
        9,
        8,
        9,
        7,
        8,
        9,
        10,
        0,
        1,
        2,
        1,
        0,
        20,
        22,
        18,
        25,
        30,
    ],
    "coffee": [
        1,
        0,
        2,
        1,
        1,
        0,
        2,
        1,
        0,
        1,
        9,
        10,
        8,
        9,
        8,
        10,
        9,
        8,
        9,
        10,
        5,
        4,
        6,
        5,
        4,
        5,
        6,
        5,
        5,
        4,
        2,
        1,
        0,
        2,
        1,
        1,
        2,
        1,
        0,
        1,
        8,
        9,
        10,
        9,
        8,
        20,
        2,
        25,
        30,
        0,
    ],
}

# %%
df=pd.DataFrame(data)

# %%
# # Performing DBSCAN
# from sklearn.cluster import DBSCAN

# X = df.drop('person', axis=1)

# dbscan = DBSCAN(eps=2, min_samples=5)

# labels = dbscan.fit_predict(X)
# labels


from sklearn.cluster import DBSCAN

X = df[["tea", "coffee"]]

dbscan = DBSCAN(eps=.3, min_samples=100)
df["cluster"] = dbscan.fit_predict(X)

df.head(10)
# Out:
#    c_id  Age  tea  coffee  greentea  cold_drink  gym_days  water_ltres  \
# 0     1   41    6       0         1           1         0          1.0
# 1     2   54    4       1         0           1         0          1.0
# 2     3   49    5       1         1           0         2          2.0
# 3     4   45    4       1         1           0         2          2.0
# 4     5   42    6       2         1           1         0          1.0
# 5     6   55    6       0         1           0         1          2.0
# 6     7   41    5       0         1           1         0          2.0
# 7     8   53    4       0         0           0         2          1.0
# 8     9   45    6       2         0           1         2          2.0
# 9    10   45    5       1         1           1         1          1.0
#
#    work_hrs  netflix_hrs  cluster
# 0         7           12       -1
# 1         7            6       -1
# 2         8            9       -1
# 3         7           11       -1
# ...

# %%
import matplotlib.pyplot as plt

# Plotting the all the clusters
plt.scatter(df["Age"], df["coffee"], c=df["cluster"], cmap="viridis")
plt.xlabel("Age")
plt.ylabel("Coffee Consumption")
plt.title("DBSCAN Clustering")
plt.colorbar(label="Cluster Label")
plt.show()

# %%
# printing out the outliers
outliers = df[labels == -1]
outliers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 2
#       1 # printing out the outliers
# ----> 2 outliers = df[labels == -1]
#       3 outliers
#
# File c:\EXL\py_env\Lib\site-packages\pandas\core\frame.py:4369, in DataFrame.__getitem__(self, key)
#    4365             return self.where(key)
#    4366
#    4367         # Do we have a (boolean) 1d indexer?
#    4368         if com.is_bool_indexer(key):
# -> 4369             return self._getitem_bool_array(key)
#    4370
#    4371         # We are left with two options: a single key, and a collection of keys,
#    4372         # We interpret tuples as collections only for non-MultiIndex
#
# File c:\EXL\py_env\Lib\site-packages\pandas\core\frame.py:4419, in DataFrame._getitem_bool_array(self, key)
#    4415                 UserWarning,
#    4416                 stacklevel=find_stack_level(),
# ...
