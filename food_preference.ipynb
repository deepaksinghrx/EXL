# %%
import numpy as np
import pandas as pd

# %%
data = {
    "food": [
        "Grilled chicken with salad",
        "Veg burger with fries",
        "Paneer butter masala with naan",
        "Boiled vegetables and quinoa",
        "Chicken biryani with raita",
        "Fruit bowl with yogurt",
        "Pizza with extra cheese",
        "Dal, rice and sabzi",
        "Fried chicken wings",
        "Oats with milk and nuts",
    ],
    "preference": [
        "healthy non veg",
        "fast food veg",
        "veg",
        "healthy veg",
        "non veg",
        "healthy veg",
        "fast food",
        "healthy veg",
        "fast food non veg",
        "healthy veg",
    ],
}
